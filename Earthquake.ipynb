# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a=pd.read_csv('train_values.csv')
a.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_agriculture  \
# 0                      t               r  ...                             0
# ...

# %%
b=pd.read_csv('train_labels.csv')
b.head()
# Out:
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             3

# %%
df=pd.merge(a,b,sort=False)
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_hotel  \
# 0                      t               r  ...                       0
# ...

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type roof_type ground_floor_type  \
# 0                      t               r         n                 f
# ...

# %%
df.shape
# Out:
# (260601, 40)

# %%
df.describe()
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# count  2.606010e+05   260601.000000   260601.000000   260601.000000
# mean   5.256755e+05       13.900353      701.074685     6257.876148
# std    3.045450e+05        8.033617      412.710734     3646.369645
# min    4.000000e+00        0.000000        0.000000        0.000000
# 25%    2.611900e+05        7.000000      350.000000     3073.000000
# 50%    5.257570e+05       12.000000      702.000000     6270.000000
# 75%    7.897620e+05       21.000000     1050.000000     9412.000000
# max    1.052934e+06       30.000000     1427.000000    12567.000000
#
#        count_floors_pre_eq            age  area_percentage  height_percentage  \
# count        260601.000000  260601.000000    260601.000000      260601.000000
# mean              2.129723      26.535029         8.018051           5.434365
# std               0.727665      73.565937         4.392231           1.918418
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260601 entries, 0 to 260600
# Data columns (total 40 columns):
# building_id                               260601 non-null int64
# geo_level_1_id                            260601 non-null int64
# geo_level_2_id                            260601 non-null int64
# geo_level_3_id                            260601 non-null int64
# count_floors_pre_eq                       260601 non-null int64
# age                                       260601 non-null int64
# area_percentage                           260601 non-null int64
# height_percentage                         260601 non-null int64
# land_surface_condition                    260601 non-null object
# foundation_type                           260601 non-null object
# roof_type                                 260601 non-null object
# ground_floor_type                         260601 non-null object
# other_floor_type                          260601 non-null object
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe(include='O')
# Out:
#        land_surface_condition foundation_type roof_type ground_floor_type  \
# count                  260601          260601    260601            260601
# unique                      3               5         3                 5
# top                         t               r         n                 f
# freq                   216757          219196    182842            209619
#
#        other_floor_type position plan_configuration legal_ownership_status
# count            260601   260601             260601                 260601
# unique                4        4                 10                      4
# top                   q        s                  d                      v
# freq             165282   202090             250072                 250939

# %%
df_new=pd.get_dummies(df,columns=['land_surface_condition','foundation_type','roof_type','ground_floor_type','other_floor_type','position','plan_configuration','legal_ownership_status'])

df_new.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# 0                             1                                    1
# ...

# %%
df_new.shape
# Out:
# (260601, 70)

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,VotingClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,f1_score,accuracy_score

# %%
from sklearn.model_selection import train_test_split

# %%
X=df_new.drop(['building_id','damage_grade'],axis=1)
y=df_new['damage_grade']

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# lr=LogisticRegressionCV(max_iter=100000)

# %%
# lr.fit(X_train,y_train)

# %%
# pred_lr=lr.predict(X_test)

# %%
# print(classification_report(y_test,pred_lr))

# %%
# print(confusion_matrix(y_test,pred_lr))

# %%
# print(accuracy_score(y_test,pred_lr))

# %%
# print(f1_score(y_test,pred_lr,average='micro'))

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X_new=pd.DataFrame(sc.fit_transform(X),columns=X.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression(max_iter=100000)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_lr=lr.predict(X_test)

# %%
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.58      0.30      0.39      7601
#            2       0.60      0.87      0.71     44414
#            3       0.54      0.20      0.30     26166
#
#     accuracy                           0.59     78181
#    macro avg       0.57      0.46      0.47     78181
# weighted avg       0.58      0.59      0.54     78181

# %%
print(confusion_matrix(y_test,pred_lr))
# Out:
# [[ 2261  5145   195]
#  [ 1520 38549  4345]
#  [  139 20710  5317]]

# %%
print(accuracy_score(y_test,pred_lr))
# Out:
# 0.5900026860746217

# %%
print(f1_score(y_test,pred_lr,average='micro'))
# Out:
# 0.5900026860746217

# %%
import xgboost as xgb

# %%
xgbc=xgb.XGBClassifier()

# %%
xgbc.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
pred_xgbc=xgbc.predict(X_test)

# %%
print(classification_report(y_test,pred_xgbc))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.70      0.45      0.55      7601
#            2       0.72      0.85      0.78     44414
#            3       0.75      0.59      0.66     26166
#
#     accuracy                           0.73     78181
#    macro avg       0.72      0.63      0.66     78181
# weighted avg       0.73      0.73      0.72     78181

# %%
print(confusion_matrix(y_test,pred_xgbc))
# Out:
# [[ 3405  4102    94]
#  [ 1341 37928  5145]
#  [   97 10581 15488]]

# %%
print(accuracy_score(y_test,pred_xgbc))
# Out:
# 0.7267878384773794

# %%
print(f1_score(y_test,pred_xgbc,average='micro'))
# Out:
# 0.7267878384773795

# %%
rf = RandomForestClassifier(random_state=42)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
pred_rf=rf.predict(X_test)

# %%
print(classification_report(y_test,pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.66      0.47      0.55      7601
#            2       0.72      0.82      0.77     44414
#            3       0.71      0.60      0.65     26166
#
#     accuracy                           0.71     78181
#    macro avg       0.69      0.63      0.65     78181
# weighted avg       0.71      0.71      0.71     78181

# %%
print(confusion_matrix(y_test,pred_rf))
# Out:
# [[ 3569  3850   182]
#  [ 1703 36521  6190]
#  [  172 10402 15592]]

# %%
print(accuracy_score(y_test,pred_rf))
# Out:
# 0.7122190813624794

# %%
print(f1_score(y_test,pred_rf,average='micro'))
# Out:
# 0.7122190813624794

# %%
ada=AdaBoostClassifier()

# %%
ada.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=None)

# %%
pred_ada=ada.predict(X_test)

# %%
print(classification_report(y_test,pred_ada))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.57      0.35      0.43      7601
#            2       0.63      0.88      0.74     44414
#            3       0.71      0.33      0.45     26166
#
#     accuracy                           0.64     78181
#    macro avg       0.64      0.52      0.54     78181
# weighted avg       0.65      0.64      0.61     78181

# %%
print(confusion_matrix(y_test,pred_ada))
# Out:
# [[ 2627  4951    23]
#  [ 1872 39018  3524]
#  [   92 17503  8571]]

# %%
print(accuracy_score(y_test,pred_ada))
# Out:
# 0.6423043962087975

# %%
print(f1_score(y_test,pred_ada,average='micro'))
# Out:
# 0.6423043962087975

# %%
gbc=GradientBoostingClassifier()

# %%
gbc.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
pred_gbc=gbc.predict(X_test)

# %%
print(classification_report(y_test,pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.65      0.38      0.47      7601
#            2       0.67      0.86      0.76     44414
#            3       0.72      0.46      0.56     26166
#
#     accuracy                           0.68     78181
#    macro avg       0.68      0.57      0.60     78181
# weighted avg       0.69      0.68      0.66     78181

# %%
print(confusion_matrix(y_test,pred_gbc))
# Out:
# [[ 2854  4688    59]
#  [ 1466 38299  4649]
#  [  100 13911 12155]]

# %%
print(accuracy_score(y_test,pred_gbc))
# Out:
# 0.6818536473056114

# %%
print(f1_score(y_test,pred_gbc,average='micro'))
# Out:
# 0.6818536473056114

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
pred_dt=dt.predict(X_test)

# %%
print(classification_report(y_test,pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.49      0.50      0.49      7601
#            2       0.71      0.71      0.71     44414
#            3       0.62      0.62      0.62     26166
#
#     accuracy                           0.66     78181
#    macro avg       0.60      0.61      0.61     78181
# weighted avg       0.66      0.66      0.66     78181

# %%
print(confusion_matrix(y_test,pred_dt))
# Out:
# [[ 3811  3242   548]
#  [ 3513 31400  9501]
#  [  532  9515 16119]]

# %%
print(accuracy_score(y_test,pred_dt))
# Out:
# 0.6565533825353986

# %%
print(f1_score(y_test,pred_dt,average='micro'))
# Out:
# 0.6565533825353986

# %%
bgc=BaggingClassifier()

# %%
bgc.fit(X_train,y_train)
# Out:
# BaggingClassifier(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                   max_features=1.0, max_samples=1.0, n_estimators=10,
#                   n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                   warm_start=False)

# %%
pred_bgc=bgc.predict(X_test)

# %%
print(classification_report(y_test,pred_bgc))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.58      0.54      0.56      7601
#            2       0.73      0.80      0.76     44414
#            3       0.71      0.60      0.65     26166
#
#     accuracy                           0.71     78181
#    macro avg       0.67      0.65      0.66     78181
# weighted avg       0.71      0.71      0.70     78181

# %%
print(confusion_matrix(y_test,pred_bgc))
# Out:
# [[ 4098  3254   249]
#  [ 2629 35456  6329]
#  [  316 10095 15755]]

# %%
print(accuracy_score(y_test,pred_bgc))
# Out:
# 0.707448101201059

# %%
print(f1_score(y_test,pred_bgc,average='micro'))
# Out:
# 0.7074481012010592

# %%
ensemble=[('Decision Tree',dt),('Random Forest',rf),('Bagging',bgc),('Gradient Boosting',gbc),('AdaBoosting',ada),('XGBClassifier',xgbc)]

# %%
vc=VotingClassifier(estimators=ensemble)

# %%
vc.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('Decision Tree',
#                               DecisionTreeClassifier(ccp_alpha=0.0,
#                                                      class_weight=None,
#                                                      criterion='gini',
#                                                      max_depth=None,
#                                                      max_features=None,
#                                                      max_leaf_nodes=None,
#                                                      min_impurity_decrease=0.0,
#                                                      min_impurity_split=None,
#                                                      min_samples_leaf=1,
#                                                      min_samples_split=2,
#                                                      min_weight_fraction_leaf=0.0,
#                                                      presort='deprecated',
# ...

# %%
pred_vc=vc.predict(X_test)

# %%
print(classification_report(y_test,pred_vc))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.65      0.50      0.57      7601
#            2       0.70      0.88      0.78     44414
#            3       0.80      0.50      0.61     26166
#
#     accuracy                           0.72     78181
#    macro avg       0.72      0.63      0.66     78181
# weighted avg       0.73      0.72      0.71     78181

# %%
print(confusion_matrix(y_test,pred_vc))
# Out:
# [[ 3821  3728    52]
#  [ 1859 39288  3267]
#  [  160 12940 13066]]

# %%
print(accuracy_score(y_test,pred_vc))
# Out:
# 0.7185249613077346

# %%
print(f1_score(y_test,pred_vc,average='micro'))
# Out:
# 0.7185249613077346

# %%
test=pd.read_csv('test_values.csv')
test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#   land_surface_condition foundation_type roof_type ground_floor_type  \
# 0                      t               r         n                 f
# ...

# %%
test.shape
# Out:
# (86868, 39)

# %%
df_t=pd.get_dummies(test,columns=['land_surface_condition','foundation_type','roof_type','ground_floor_type','other_floor_type','position','plan_configuration','legal_ownership_status'])

df_t.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# 0                             0                                    1
# ...

# %%
df_t.shape
# Out:
# (86868, 69)

# %%
b=df_t['building_id']

# %%
df_t.drop(['building_id'],axis=1,inplace=True)

# %%
X_t=pd.DataFrame(sc.fit_transform(df_t),columns=df_t.columns)

# %%
pred_xgbc_test=xgbc.predict(X_t)

# %%
new=pd.DataFrame()

# %%
new['building_id']=pd.Series(b)

# %%
new['damage_grade']=pd.Series(pred_xgbc_test)

# %%
new['damage_grade'].value_counts()
# Out:
# 2    59539
# 3    22121
# 1     5208
# Name: damage_grade, dtype: int64

# %%
new
# Out:
#        building_id  damage_grade
# 0           300051             3
# 1            99355             2
# 2           890251             2
# 3           745817             1
# 4           421793             3
# ...            ...           ...
# 86863       310028             2
# 86864       663567             3
# 86865      1049160             2
# 86866       442785             2
# 86867       501372             2
#
# [86868 rows x 2 columns]

# %%
new.to_csv (r'C:\Users\lenovo\Desktop\Python\Driven Data\Submission.csv', index = False)
